# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing Dataset

# %%
data = pd.read_csv('OmdenaDatasetEDATeam.csv')
data
# Out:
#        Unnamed: 0      time  weathercode  temperature_2m_max  \
# 0               0  1/1/2010            0                26.0
# 1               1  1/2/2010            2                25.3
# 2               2  1/3/2010            0                25.0
# 3               3  1/4/2010            0                25.6
# 4               4  1/5/2010            0                25.4
# ...           ...       ...          ...                 ...
# 34757       34757  8/2/2023           51                30.2
# 34758       34758  8/3/2023           51                30.4
# 34759       34759  8/4/2023           51                30.5
# 34760       34760  8/5/2023           51                30.7
# 34761       34761  8/6/2023           51                30.7
#
#        temperature_2m_min  temperature_2m_mean  apparent_temperature_max  \
# 0                    14.8                 20.9                      24.0
# 1                    15.6                 20.5                      21.8
# ...

# %% [markdown]
# # Gaining Insights

# %%
data.describe()
# Out:
#          Unnamed: 0   weathercode  temperature_2m_max  temperature_2m_min  \
# count  34762.000000  34762.000000        34762.000000        34762.000000
# mean   17380.500000     24.229417           30.677150           23.205748
# std    10035.069365     27.551242            3.236343            3.615309
# min        0.000000      0.000000           17.700000            6.800000
# 25%     8690.250000      1.000000           28.300000           21.700000
# 50%    17380.500000      2.000000           30.500000           24.200000
# 75%    26070.750000     53.000000           32.800000           25.500000
# max    34761.000000     65.000000           44.300000           32.500000
#
#        temperature_2m_mean  apparent_temperature_max  \
# count         34762.000000              34762.000000
# mean             26.674475                 33.920612
# std               2.733634                  4.309410
# min              13.200000                 11.800000
# ...

# %% [markdown]
# # Calculating precipitation rate

# %%
data['time'] = pd.to_datetime(data['time'], format='%m/%d/%Y')
total_precipitation = data['precipitation_sum']

# %%
total_hours = data['precipitation_hours'].sum()

# %%
data['precipitation_rate'] = total_precipitation/total_hours

# %%
data['precipitation_rate'].isnull().sum()
# Out:
# 0

# %%
data.head()
# Out:
#    Unnamed: 0       time  weathercode  temperature_2m_max  temperature_2m_min  \
# 0           0 2010-01-01            0                26.0                14.8
# 1           1 2010-01-02            2                25.3                15.6
# 2           2 2010-01-03            0                25.0                14.3
# 3           3 2010-01-04            0                25.6                15.0
# 4           4 2010-01-05            0                25.4                16.3
#
#    temperature_2m_mean  apparent_temperature_max  apparent_temperature_min  \
# 0                 20.9                      24.0                      13.4
# 1                 20.5                      21.8                      13.7
# 2                 19.9                      22.8                      14.2
# 3                 20.4                      23.9                      13.7
# 4                 20.7                      24.5                      16.8
#
# ...

# %% [markdown]
# # Filtering rest cities

# %%
karachi = data[data['city'] == 'Karachi']
karachi
# Out:
#       Unnamed: 0       time  weathercode  temperature_2m_max  \
# 0              0 2010-01-01            0                26.0
# 1              1 2010-01-02            2                25.3
# 2              2 2010-01-03            0                25.0
# 3              3 2010-01-04            0                25.6
# 4              4 2010-01-05            0                25.4
# ...          ...        ...          ...                 ...
# 4961        4961 2023-08-02           51                30.3
# 4962        4962 2023-08-03           51                30.0
# 4963        4963 2023-08-04            3                30.2
# 4964        4964 2023-08-05           51                30.0
# 4965        4965 2023-08-06           51                29.4
#
#       temperature_2m_min  temperature_2m_mean  apparent_temperature_max  \
# 0                   14.8                 20.9                      24.0
# 1                   15.6                 20.5                      21.8
# ...

# %% [markdown]
# # Precipitation rate of nearby karachi

# %%
for city, group_data in filtered_df.groupby('city'):
    plt.figure(figsize=(10, 6))
    plt.plot(group_data['time'], group_data['precipitation_rate'], label=city)
    plt.title('precipitation_rate for %s' % city)
    plt.xlabel('Year')
    plt.ylabel('precipitation')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Precipitation rate of karachi

# %%
plt.title('Precipitation Rate in Karachi')
plt.xlabel('Year')
plt.ylabel('Precipitation')
plt.plot(karachi['time'], karachi['precipitation_rate'], label='Karachi')
plt.show()

# %% [markdown]
# # Calculating precipitation sum for nearby cities

# %%
start_date = '5-1-2021'
end_date = '11-1-2021'
filtered_df = data[(data['time'] >= start_date) & (data['time'] <= end_date)]

for city, group_data in filtered_df.groupby('city'):
    plt.plot(group_data['time'], group_data['precipitation_sum'], label=city)

plt.title('Precipitation Sum by City')
plt.xlabel('Date')
plt.ylabel('Precipitation')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Precipitation sum for karachi

# %%
plt.figure(figsize=(10, 6))
city_df = filtered_df[filtered_df['city'] == 'Karachi']
plt.plot(city_df['time'], city_df['precipitation_sum'], label='Karachi')

plt.title('Precipitation Sum of Karachi')
plt.xlabel('Year')
plt.ylabel('Precipitation')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
