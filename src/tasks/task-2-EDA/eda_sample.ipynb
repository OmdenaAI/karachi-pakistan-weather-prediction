# %% [markdown]
# The first thing we need to do here is to import the libraries we need.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# After that, we need to import the data from the csv. For simplicity, I put the data in the root of this folder.

# %%
data = pd.read_csv('open_meteo.csv')
data.head()
# Out:
#    Unnamed: 0      time  weathercode  temperature_2m_max  temperature_2m_min  \
# 0           0  1/1/2010            0                26.0                14.8
# 1           1  1/2/2010            2                25.3                15.6
# 2           2  1/3/2010            0                25.0                14.3
# 3           3  1/4/2010            0                25.6                15.0
# 4           4  1/5/2010            0                25.4                16.3
#
#    temperature_2m_mean  apparent_temperature_max  apparent_temperature_min  \
# 0                 20.9                      24.0                      13.4
# 1                 20.5                      21.8                      13.7
# 2                 19.9                      22.8                      14.2
# 3                 20.4                      23.9                      13.7
# 4                 20.7                      24.5                      16.8
#
# ...

# %%
data.shape
# Out:
# (34762, 25)

# %%
data.describe()
# Out:
#          Unnamed: 0   weathercode  temperature_2m_max  temperature_2m_min  \
# count  34762.000000  34762.000000        34762.000000        34762.000000
# mean   17380.500000     24.229417           30.677150           23.205748
# std    10035.069365     27.551242            3.236343            3.615309
# min        0.000000      0.000000           17.700000            6.800000
# 25%     8690.250000      1.000000           28.300000           21.700000
# 50%    17380.500000      2.000000           30.500000           24.200000
# 75%    26070.750000     53.000000           32.800000           25.500000
# max    34761.000000     65.000000           44.300000           32.500000
#
#        temperature_2m_mean  apparent_temperature_max  \
# count         34762.000000              34762.000000
# mean             26.674475                 33.920612
# std               2.733634                  4.309410
# min              13.200000                 11.800000
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                    0
# time                          0
# weathercode                   0
# temperature_2m_max            0
# temperature_2m_min            0
# temperature_2m_mean           0
# apparent_temperature_max      0
# apparent_temperature_min      0
# apparent_temperature_mean     0
# sunrise                       0
# sunset                        0
# shortwave_radiation_sum       0
# precipitation_sum             0
# rain_sum                      0
# snowfall_sum                  0
# precipitation_hours           0
# windspeed_10m_max             0
# windgusts_10m_max             0
# winddirection_10m_dominant    0
# et0_fao_evapotranspiration    0
# latitude                      0
# longitude                     0
# elevation                     0
# country                       0
# city                          0
# dtype: int64

# %%
data.dtypes
# Out:
# Unnamed: 0                      int64
# time                           object
# weathercode                     int64
# temperature_2m_max            float64
# temperature_2m_min            float64
# temperature_2m_mean           float64
# apparent_temperature_max      float64
# apparent_temperature_min      float64
# apparent_temperature_mean     float64
# sunrise                        object
# sunset                         object
# shortwave_radiation_sum       float64
# precipitation_sum             float64
# rain_sum                      float64
# snowfall_sum                    int64
# precipitation_hours             int64
# windspeed_10m_max             float64
# windgusts_10m_max             float64
# winddirection_10m_dominant      int64
# et0_fao_evapotranspiration    float64
# latitude                      float64
# longitude                     float64
# elevation                       int64
# country                        object
# city                           object
# ...

# %%
data['time'] = pd.to_datetime(data['time'], format='%m/%d/%Y')
data.dtypes
# Out:
# Unnamed: 0                             int64
# time                          datetime64[ns]
# weathercode                            int64
# temperature_2m_max                   float64
# temperature_2m_min                   float64
# temperature_2m_mean                  float64
# apparent_temperature_max             float64
# apparent_temperature_min             float64
# apparent_temperature_mean            float64
# sunrise                               object
# sunset                                object
# shortwave_radiation_sum              float64
# precipitation_sum                    float64
# rain_sum                             float64
# snowfall_sum                           int64
# precipitation_hours                    int64
# windspeed_10m_max                    float64
# windgusts_10m_max                    float64
# winddirection_10m_dominant             int64
# et0_fao_evapotranspiration           float64
# latitude                             float64
# ...

# %%
data = data[['time', 'city', 'latitude', 'temperature_2m_min', 'temperature_2m_max', 'temperature_2m_mean', 'precipitation_sum', 'precipitation_hours', 'windspeed_10m_max', 'windgusts_10m_max']]
data['precipitation_rate'] = data['precipitation_sum'] / data['precipitation_hours']
data['precipitation_rate'].fillna(0, inplace=True)
data.head()
# Out:
#         time     city   latitude  temperature_2m_min  temperature_2m_max  \
# 0 2010-01-01  Karachi  24.900002                14.8                26.0
# 1 2010-01-02  Karachi  24.900002                15.6                25.3
# 2 2010-01-03  Karachi  24.900002                14.3                25.0
# 3 2010-01-04  Karachi  24.900002                15.0                25.6
# 4 2010-01-05  Karachi  24.900002                16.3                25.4
#
#    temperature_2m_mean  precipitation_sum  precipitation_hours  \
# 0                 20.9                0.0                    0
# 1                 20.5                0.0                    0
# 2                 19.9                0.0                    0
# 3                 20.4                0.0                    0
# 4                 20.7                0.0                    0
#
#    windspeed_10m_max  windgusts_10m_max  precipitation_rate
# 0               18.3               25.6                 0.0
# ...

# %%
plt.figure(figsize=(10, 6))

for city, group_data in data.groupby('city'):
    plt.plot(group_data['time'], group_data['precipitation_rate'], label=city)

plt.title('Precipitation Rate by City')
plt.xlabel('Date')
plt.ylabel('Precipitation')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
start_date = '5-1-2021'
end_date = '11-1-2021'
filtered_df = data[(data['time'] >= start_date) & (data['time'] <= end_date)]

plt.figure(figsize=(10, 6))

for city, group_data in filtered_df.groupby('city'):
    plt.plot(group_data['time'], group_data['precipitation_rate'], label=city)

plt.title('Precipitation Rate by City')
plt.xlabel('Date')
plt.ylabel('Precipitation')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
city_df = filtered_df[filtered_df['city'] == 'Karachi']

plt.figure(figsize=(10, 6))

plt.plot(city_df['time'], city_df['precipitation_rate'], label='Karachi')

plt.title('Precipitation Rate of Karachi')
plt.xlabel('Date')
plt.ylabel('Precipitation')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

for city, group_data in filtered_df.groupby('city'):
    plt.plot(group_data['time'], group_data['precipitation_sum'], label=city)

plt.title('Precipitation Sum by City')
plt.xlabel('Date')
plt.ylabel('Precipitation')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(city_df['time'], city_df['precipitation_sum'], label='Karachi')

plt.title('Precipitation Sum of Karachi')
plt.xlabel('Date')
plt.ylabel('Precipitation')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
