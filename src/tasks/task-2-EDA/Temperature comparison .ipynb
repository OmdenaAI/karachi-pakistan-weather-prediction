# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
data = pd.read_csv('open_meteo.csv')
data
# Out:
#        Unnamed: 0        time  weathercode  temperature_2m_max  \
# 0               0  2010-01-01            0                26.0
# 1               1  2010-01-02            2                25.3
# 2               2  2010-01-03            0                25.0
# 3               3  2010-01-04            0                25.6
# 4               4  2010-01-05            0                25.4
# ...           ...         ...          ...                 ...
# 34757       34757  2023-08-02           51                30.2
# 34758       34758  2023-08-03           51                30.4
# 34759       34759  2023-08-04           51                30.5
# 34760       34760  2023-08-05           51                30.7
# 34761       34761  2023-08-06           51                30.7
#
#        temperature_2m_min  temperature_2m_mean  apparent_temperature_max  \
# 0                    14.8                 20.9                      24.0
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0   weathercode  temperature_2m_max  temperature_2m_min  \
# count  34762.000000  34762.000000        34762.000000        34762.000000
# mean   17380.500000     24.229417           30.677150           23.205748
# std    10035.069365     27.551242            3.236343            3.615309
# min        0.000000      0.000000           17.700000            6.800000
# 25%     8690.250000      1.000000           28.300000           21.700000
# 50%    17380.500000      2.000000           30.500000           24.200000
# 75%    26070.750000     53.000000           32.800000           25.500000
# max    34761.000000     65.000000           44.300000           32.500000
#
#        temperature_2m_mean  apparent_temperature_max  \
# count         34762.000000              34762.000000
# mean             26.674475                 33.920612
# std               2.733634                  4.309410
# min              13.200000                 11.800000
# ...

# %%
data = data[['time', 'city', 'temperature_2m_min', 'temperature_2m_max', 'temperature_2m_mean', 'precipitation_sum', 'precipitation_hours', 'et0_fao_evapotranspiration']]
data
# Out:
#              time     city  temperature_2m_min  temperature_2m_max  \
# 0      2010-01-01  Karachi                14.8                26.0
# 1      2010-01-02  Karachi                15.6                25.3
# 2      2010-01-03  Karachi                14.3                25.0
# 3      2010-01-04  Karachi                15.0                25.6
# 4      2010-01-05  Karachi                16.3                25.4
# ...           ...      ...                 ...                 ...
# 34757  2023-08-02     Bhuj                25.5                30.2
# 34758  2023-08-03     Bhuj                25.4                30.4
# 34759  2023-08-04     Bhuj                25.5                30.5
# 34760  2023-08-05     Bhuj                25.6                30.7
# 34761  2023-08-06     Bhuj                25.4                30.7
#
#        temperature_2m_mean  precipitation_sum  precipitation_hours  \
# 0                     20.9                0.0                  0.0
# ...

# %%
data['time'] = pd.to_datetime(data['time'], format='%Y/%m/%d')
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
start_date = '5-1-2022'
end_date = '12-1-2022'
df = data[(data['time'] >= start_date) & (data['time'] <= end_date)]

# %%
df
# Out:
#             time     city  temperature_2m_min  temperature_2m_max  \
# 4503  2022-05-01  Karachi                28.0                36.2
# 4504  2022-05-02  Karachi                26.6                33.1
# 4505  2022-05-03  Karachi                26.1                33.5
# 4506  2022-05-04  Karachi                25.5                32.9
# 4507  2022-05-05  Karachi                25.0                33.0
# ...          ...      ...                 ...                 ...
# 34509 2022-11-27     Bhuj                15.4                29.8
# 34510 2022-11-28     Bhuj                14.7                29.8
# 34511 2022-11-29     Bhuj                14.1                29.4
# 34512 2022-11-30     Bhuj                15.0                30.0
# 34513 2022-12-01     Bhuj                14.9                29.0
#
#        temperature_2m_mean  precipitation_sum  precipitation_hours  \
# 4503                  31.8                0.0                  0.0
# ...

# %% [markdown]
# ### Which city has low temperature and high temperature?

# %%
low_temp = df['temperature_2m_min'].min()
df[df['temperature_2m_min'] == low_temp]
# Out:
#             time  city  temperature_2m_min  temperature_2m_max  \
# 34511 2022-11-29  Bhuj                14.1                29.4
#
#        temperature_2m_mean  precipitation_sum  precipitation_hours  \
# 34511                 21.8                0.0                  0.0
#
#        et0_fao_evapotranspiration
# 34511                        5.08

# %% [markdown]
# We can see that Bhuj has low temperature than the other cities.
# The city was not too hot at 2022 November

# %%
high_temp = df['temperature_2m_max'].max()
df[df['temperature_2m_max'] == high_temp]
# Out:
#             time  city  temperature_2m_min  temperature_2m_max  \
# 34310 2022-05-12  Bhuj                25.2                42.2
# 34353 2022-06-24  Bhuj                27.8                42.2
#
#        temperature_2m_mean  precipitation_sum  precipitation_hours  \
# 34310                 32.9                0.0                  0.0
# 34353                 34.6                0.0                  0.0
#
#        et0_fao_evapotranspiration
# 34310                       10.16
# 34353                        8.29

# %% [markdown]
# From the above, The maximum temperature recorded in Bhuj was 42.2°C. The months of May and June are indeed known for higher temperatures and heatwaves in Bhuj.

# %% [markdown]
# ### Minimum Temperature and Maximum Temperature Plot for 2022

# %%
fig = px.line(df, x="time", y="temperature_2m_min", title='Minimum Temperature for each day',color='city')
fig2 = px.line(df, x="time", y="temperature_2m_max", title='Maximum Temperature for each day',color='city')
fig3 = px.line(df, x="time", y="temperature_2m_mean", title='Average Temperature for each day',color='city')

fig.show()
fig2.show()
fig3.show()
# Out:
# <div>                            <div id="14d5428f-6373-4060-89b5-fbe2a93f9efa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14d5428f-6373-4060-89b5-fbe2a93f9efa")) {                    Plotly.newPlot(                        "14d5428f-6373-4060-89b5-fbe2a93f9efa",                        [{"hovertemplate":"city=Karachi<br>time=%{x}<br>temperature_2m_min=%{y}<extra></extra>","legendgroup":"Karachi","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Karachi","showlegend":true,"x":["2022-05-01T00:00:00","2022-05-02T00:00:00","2022-05-03T00:00:00","2022-05-04T00:00:00","2022-05-05T00:00:00","2022-05-06T00:00:00","2022-05-07T00:00:00","2022-05-08T00:00:00","2022-05-09T00:00:00","2022-05-10T00:00:00","2022-05-1
# ...

# %% [markdown]
# From the above plot, we can see that all of the cities temperature. For instance, in 2020, in July, the minimum temperature is 28.9 degrees Celsius and the high temperature is 30 degrees Celsius in May. From these plots, we can conclude that the high temperature occurs around May, June, and October.

# %% [markdown]
# ### Minimum Temperature and Maximum Temperature Plot for 2021

# %%
start_date = '5-1-2021'
end_date = '12-1-2021'
df2 = data[(data['time'] >= start_date) & (data['time'] <= end_date)]

# %%
fig = px.line(df2, x="time", y="temperature_2m_min", title='Minimum Temperature for each day',color='city')
fig2 = px.line(df2, x="time", y="temperature_2m_max", title='Maximum Temperature for each day',color='city')
fig.show()
fig2.show()
# Out:
# <div>                            <div id="94d57a66-cf66-46c9-9988-5410068296bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94d57a66-cf66-46c9-9988-5410068296bb")) {                    Plotly.newPlot(                        "94d57a66-cf66-46c9-9988-5410068296bb",                        [{"hovertemplate":"city=Karachi<br>time=%{x}<br>temperature_2m_min=%{y}<extra></extra>","legendgroup":"Karachi","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Karachi","showlegend":true,"x":["2021-05-01T00:00:00","2021-05-02T00:00:00","2021-05-03T00:00:00","2021-05-04T00:00:00","2021-05-05T00:00:00","2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-08T00:00:00","2021-05-09T00:00:00","2021-05-10T00:00:00","2021-05-1
# ...

# %% [markdown]
# From the above graphs, we can clearly see that the high temperature in December 2021 was 30.1 degrees Celsius. From the previous graph, the high temperature in December 2022 was 28.7 degrees Celsius. That means last year's temperature was not as hot as 2021.

# %%
df
# Out:
#             time     city  temperature_2m_min  temperature_2m_max  \
# 4503  2022-05-01  Karachi                28.0                36.2
# 4504  2022-05-02  Karachi                26.6                33.1
# 4505  2022-05-03  Karachi                26.1                33.5
# 4506  2022-05-04  Karachi                25.5                32.9
# 4507  2022-05-05  Karachi                25.0                33.0
# ...          ...      ...                 ...                 ...
# 34509 2022-11-27     Bhuj                15.4                29.8
# 34510 2022-11-28     Bhuj                14.7                29.8
# 34511 2022-11-29     Bhuj                14.1                29.4
# 34512 2022-11-30     Bhuj                15.0                30.0
# 34513 2022-12-01     Bhuj                14.9                29.0
#
#        temperature_2m_mean  precipitation_sum  precipitation_hours  \
# 4503                  31.8                0.0                  0.0
# ...

# %% [markdown]
# ### Most heat waves period

# %%
temperature_threshold = 30 
heatwave_periods = df[df['temperature_2m_max'] > temperature_threshold]
heatwave_periods
# Out:
#             time     city  temperature_2m_min  temperature_2m_max  \
# 4503  2022-05-01  Karachi                28.0                36.2
# 4504  2022-05-02  Karachi                26.6                33.1
# 4505  2022-05-03  Karachi                26.1                33.5
# 4506  2022-05-04  Karachi                25.5                32.9
# 4507  2022-05-05  Karachi                25.0                33.0
# ...          ...      ...                 ...                 ...
# 34502 2022-11-20     Bhuj                17.1                30.6
# 34503 2022-11-21     Bhuj                17.1                30.7
# 34504 2022-11-22     Bhuj                16.5                30.5
# 34505 2022-11-23     Bhuj                16.3                30.5
# 34506 2022-11-24     Bhuj                16.2                30.1
#
#        temperature_2m_mean  precipitation_sum  precipitation_hours  \
# 4503                  31.8                0.0                  0.0
# ...

# %%
px.line(heatwave_periods,x='time',y='temperature_2m_max',title='Heat waves periods',color='city')
# Out:
# <div>                            <div id="17a71d23-00a4-4d69-bc62-9a91fb45048a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17a71d23-00a4-4d69-bc62-9a91fb45048a")) {                    Plotly.newPlot(                        "17a71d23-00a4-4d69-bc62-9a91fb45048a",                        [{"hovertemplate":"city=Karachi<br>time=%{x}<br>temperature_2m_max=%{y}<extra></extra>","legendgroup":"Karachi","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Karachi","orientation":"v","showlegend":true,"x":["2022-05-01T00:00:00","2022-05-02T00:00:00","2022-05-03T00:00:00","2022-05-04T00:00:00","2022-05-05T00:00:00","2022-05-06T00:00:00","2022-05-07T00:00:00","2022-05-08T00:00:00","2022-05-09T00:00:00","2022-05-10T00
# ...

# %% [markdown]
# Bhuj city causes heat waves other than those in other countries. Karachi doesn't have as many heatwaves as Bhuj. The high temperatures occur in May and June.

# %% [markdown]
# ### Correlation for each city

# %%
df.groupby('city').temperature_2m_min.describe()
# Out:
#             count       mean       std   min    25%   50%   75%   max
# city
# Bhuj        215.0  23.886512  3.043402  14.1  23.15  24.9  25.8  28.6
# Karachi     215.0  25.377209  2.519400  15.8  24.75  26.3  27.0  28.9
# Mangalore   215.0  24.253953  1.036110  20.6  23.80  24.3  24.7  28.0
# Mumbai      215.0  25.008837  1.965917  19.4  24.50  25.4  25.9  28.4
# Old Goa     215.0  24.495349  1.755705  18.5  24.10  24.8  25.3  28.9
# Surat       215.0  25.037674  2.410341  17.4  24.80  25.6  26.5  28.5
# Trivandrum  215.0  23.800000  0.646414  22.0  23.50  23.8  24.1  26.3

# %% [markdown]
# Temperatures range from 18.5°C to 28.9°C, with an average around 24.5°C. The temperature distribution is somewhat narrow, with a standard deviation of 1.76°C.

# %%
df.groupby('city').temperature_2m_max.describe()
# Out:
#             count       mean       std   min    25%   50%    75%   max
# city
# Bhuj        215.0  33.297209  3.636303  25.6  30.45  32.2  35.85  42.2
# Karachi     215.0  31.533953  2.143652  27.7  29.85  31.3  33.00  38.0
# Mangalore   215.0  28.545581  1.706137  25.1  27.40  28.6  29.60  33.2
# Mumbai      215.0  29.600465  2.053251  25.7  27.90  29.4  31.35  34.4
# Old Goa     215.0  30.548837  2.598397  25.4  28.45  30.2  32.80  36.4
# Surat       215.0  30.652558  2.211351  26.4  28.95  30.4  32.30  37.6
# Trivandrum  215.0  27.556279  1.002168  24.6  27.05  27.6  28.10  30.5

# %% [markdown]
# The mean maximum temperature is about 31.5°C, with temperatures ranging from 27.7°C to 38.0°C. The distribution is relatively tight, with a standard deviation of 2.14°C.

# %%
city_corr = pd.pivot_table(df, values='temperature_2m_max', index=['time'], columns=['city'])
city_corr
# Out:
# city        Bhuj  Karachi  Mangalore  Mumbai   Old Goa  Surat  Trivandrum
# time
# 2022-05-01  40.9     36.2       31.5     32.9     33.8   34.0        29.8
# 2022-05-02  39.0     33.1       32.6     32.8     34.1   34.1        29.9
# 2022-05-03  36.0     33.5       33.2     33.1     34.8   33.6        30.5
# 2022-05-04  37.5     32.9       32.5     32.7     36.4   34.0        29.8
# 2022-05-05  38.3     33.0       31.2     33.0     34.6   34.4        29.6
# ...          ...      ...        ...      ...      ...    ...         ...
# 2022-11-27  29.8     27.7       29.2     30.3     31.3   29.8        27.4
# 2022-11-28  29.8     28.8       29.4     30.1     30.5   29.2        28.0
# 2022-11-29  29.4     29.6       29.9     29.6     30.9   30.2        28.0
# 2022-11-30  30.0     29.7       30.9     31.1     34.0   30.7        28.4
# 2022-12-01  29.0     28.7       30.7     30.8     33.9   30.1        28.4
#
# [215 rows x 7 columns]

# %%
city_corr.corr()
# Out:
# city            Bhuj   Karachi  Mangalore   Mumbai    Old Goa     Surat  \
# city
# Bhuj        1.000000  0.733117   0.257518  0.664624  0.376890  0.806565
# Karachi     0.733117  1.000000  -0.039880  0.301256  0.055800  0.398236
# Mangalore   0.257518 -0.039880   1.000000  0.647333  0.858273  0.525153
# Mumbai      0.664624  0.301256   0.647333  1.000000  0.767799  0.892983
# Old Goa     0.376890  0.055800   0.858273  0.767799  1.000000  0.636389
# Surat       0.806565  0.398236   0.525153  0.892983  0.636389  1.000000
# Trivandrum  0.269952  0.099011   0.466729  0.252060  0.293971  0.294217
#
# city        Trivandrum
# city
# Bhuj          0.269952
# Karachi       0.099011
# Mangalore     0.466729
# Mumbai        0.252060
# Old Goa       0.293971
# Surat         0.294217
# Trivandrum    1.000000

# %% [markdown]
# The correlation between Bhuj and Karachi has high correlation based on maximum temperature. When the maximum temperature in Bhuj tends to increase, the maximum temperature in Karachi also tends to increase, and vice versa.
