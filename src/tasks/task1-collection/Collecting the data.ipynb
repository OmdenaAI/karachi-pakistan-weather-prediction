# %%
import requests
import pandas as pd

# %%
def main():
    url = "https://archive-api.open-meteo.com/v1/archive"
    cities = [
        { "name": "Karachi", "country": "Pakistan", "latitude": 24.8608, "longitude": 67.0104 },
        { "name": "Trivandrum", "country": "India", "latitude":8.4855, "longitude": 76.9492 },
        { "name": "Mangalore", "country": "India", "latitude": 12.9172, "longitude": 74.856},
        { "name": "Old Goa", "country": "India", "latitude": 15.4438, "longitude": 73.8857 },
        { "name": "Mumbai ", "country": "India", "latitude": 19.0728, "longitude": 72.8826 },
        { "name": "Surat", "country": "India", "latitude": 21.1959, "longitude": 72.8302 },
        { "name": "Bhuj", "country": "India", "latitude": 23.254, "longitude": 69.6693 },
    ]
    cities_df =[]
    for city in cities:
        params = {"latitude":city["latitude"],
                "longitude":city['longitude'],
                "start_date": "2010-01-01",
                "end_date": "2023-08-06",
                "daily": "weathercode,temperature_2m_max,temperature_2m_min,temperature_2m_mean,apparent_temperature_max,apparent_temperature_min,apparent_temperature_mean,sunrise,sunset,shortwave_radiation_sum,precipitation_sum,rain_sum,snowfall_sum,precipitation_hours,windspeed_10m_max,windgusts_10m_max,winddirection_10m_dominant,et0_fao_evapotranspiration",
                "timezone": "GMT",
                "min": "2010-01-01",
                "max": "2023-08-06",
        }
        res = requests.get(url, params=params)

        data = res.json()
        #print(data)
        df = pd.DataFrame(data["daily"])
        df["latitude"] = data["latitude"]
        df["longitude"] = data["longitude"]
        df["elevation"] = data["elevation"]
        df["country"] = city["country"]
        df["city"] = city["name"]
        cities_df.append(df)
    concat_df = pd.concat(cities_df, ignore_index=True)
    concat_df.to_csv('open_meteo.csv')



if __name__ == "__main__":
    main()

# %%
df = pd.read_csv('open_meteo.csv')
df
# Out:
#        Unnamed: 0        time  weathercode  temperature_2m_max  \
# 0               0  2010-01-01            0                26.0
# 1               1  2010-01-02            2                25.3
# 2               2  2010-01-03            0                25.0
# 3               3  2010-01-04            0                25.6
# 4               4  2010-01-05            0                25.4
# ...           ...         ...          ...                 ...
# 34757       34757  2023-08-02           51                30.2
# 34758       34758  2023-08-03           51                30.4
# 34759       34759  2023-08-04           51                30.5
# 34760       34760  2023-08-05           51                30.7
# 34761       34761  2023-08-06           51                30.7
#
#        temperature_2m_min  temperature_2m_mean  apparent_temperature_max  \
# 0                    14.8                 20.9                      24.0
# ...

# %%
df.time.unique()
# Out:
# array(['2010-01-01', '2010-01-02', '2010-01-03', ..., '2023-08-04',
#        '2023-08-05', '2023-08-06'], dtype=object)

# %%
df.time.value_counts()
# Out:
# 2010-01-01    7
# 2019-01-22    7
# 2019-01-29    7
# 2019-01-28    7
# 2019-01-27    7
#              ..
# 2014-07-13    7
# 2014-07-12    7
# 2014-07-11    7
# 2014-07-10    7
# 2023-08-06    7
# Name: time, Length: 4966, dtype: int64

# %%
df[df.time=='2010-01-01']
# Out:
#        Unnamed: 0        time  weathercode  temperature_2m_max  \
# 0               0  2010-01-01            0                26.0
# 4966         4966  2010-01-01           51                29.8
# 9932         9932  2010-01-01            2                30.3
# 14898       14898  2010-01-01           51                33.9
# 19864       19864  2010-01-01            1                30.7
# 24830       24830  2010-01-01            1                29.3
# 29796       29796  2010-01-01            1                27.1
#
#        temperature_2m_min  temperature_2m_mean  apparent_temperature_max  \
# 0                    14.8                 20.9                      24.0
# 4966                 23.5                 26.5                      35.7
# 9932                 23.4                 26.9                      35.5
# 14898                22.9                 28.0                      38.6
# 19864                20.3                 25.3                      33.7
# ...

# %%
df.groupby('country').get_group('India')
# Out:
#        Unnamed: 0        time  weathercode  temperature_2m_max  \
# 4966         4966  2010-01-01           51                29.8
# 4967         4967  2010-01-02            2                29.2
# 4968         4968  2010-01-03            2                29.5
# 4969         4969  2010-01-04           51                28.7
# 4970         4970  2010-01-05            2                28.8
# ...           ...         ...          ...                 ...
# 34757       34757  2023-08-02           51                30.2
# 34758       34758  2023-08-03           51                30.4
# 34759       34759  2023-08-04           51                30.5
# 34760       34760  2023-08-05           51                30.7
# 34761       34761  2023-08-06           51                30.7
#
#        temperature_2m_min  temperature_2m_mean  apparent_temperature_max  \
# 4966                 23.5                 26.5                      35.7
# ...

# %%
df[df['country']=='India']
# Out:
#        Unnamed: 0        time  weathercode  temperature_2m_max  \
# 4966         4966  2010-01-01           51                29.8
# 4967         4967  2010-01-02            2                29.2
# 4968         4968  2010-01-03            2                29.5
# 4969         4969  2010-01-04           51                28.7
# 4970         4970  2010-01-05            2                28.8
# ...           ...         ...          ...                 ...
# 34757       34757  2023-08-02           51                30.2
# 34758       34758  2023-08-03           51                30.4
# 34759       34759  2023-08-04           51                30.5
# 34760       34760  2023-08-05           51                30.7
# 34761       34761  2023-08-06           51                30.7
#
#        temperature_2m_min  temperature_2m_mean  apparent_temperature_max  \
# 4966                 23.5                 26.5                      35.7
# ...

# %%
df[df['city']=='Bhuj']
# Out:
#        Unnamed: 0        time  weathercode  temperature_2m_max  \
# 29796       29796  2010-01-01            1                27.1
# 29797       29797  2010-01-02           55                21.0
# 29798       29798  2010-01-03            1                25.0
# 29799       29799  2010-01-04            0                24.9
# 29800       29800  2010-01-05            0                24.7
# ...           ...         ...          ...                 ...
# 34757       34757  2023-08-02           51                30.2
# 34758       34758  2023-08-03           51                30.4
# 34759       34759  2023-08-04           51                30.5
# 34760       34760  2023-08-05           51                30.7
# 34761       34761  2023-08-06           51                30.7
#
#        temperature_2m_min  temperature_2m_mean  apparent_temperature_max  \
# 29796                12.9                 20.4                      24.5
# ...

# %%
df.weathercode.unique()
# Out:
# array([ 0,  2, 51,  1,  3, 61, 53, 63, 65, 55], dtype=int64)

# %%
def main():
    url = "https://flood-api.open-meteo.com/v1/flood"
    
    cities = [
        { "name": "Karachi", "country": "Pakistan", "latitude": 24.8608, "longitude": 67.0104 },
    ]

    cities_dfs = []
    for city in cities:
        params = {
            "latitude": city["latitude"],
            "longitude": city["longitude"],
            "start_date": "2010-01-01",
            "end_date": "2023-08-06",
            "daily": "river_discharge_mean,river_discharge_max,river_discharge_min",
        }

        print(f"Querying flood API for {city['name']} - {city['country']}...")
        res = requests.get(url, params=params)

        if res.status_code != 200:
            res.raise_for_status()
            raise RuntimeError(
                f"Request to {url} returned status code {res.status_code}"
            )

        data = res.json()
        print(data)
        print("Preprocessing...")
        daily_data = data["daily"]
        df = pd.DataFrame(daily_data)
        df["latitude"] = city["latitude"]
        df["longitude"] = city["longitude"]
        df["country"] = city["country"]
        df["city"] = city["name"]

        cities_dfs.append(df)

    concat_df = pd.concat(cities_dfs, ignore_index=True)
    file_name = "open_meteo_flood.csv"
    concat_df.to_csv(file_name, index=False)

if __name__ == "__main__":
    main()
# Out:
# Querying flood API for Karachi - Pakistan...
# ...
